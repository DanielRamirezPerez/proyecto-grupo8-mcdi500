# %% [markdown]
# # F1 — Definición del proyecto
# **MCDI500 · Programación para la ciencia de datos**
#
# Integrantes:
# - Abigail Roblez Chavez
# - Daniel Pérez Ramirez
# - Matias Manriquez Ortiz
# - Roberto Sánchez Saldivia
#
# > **Alcance de este cuaderno (Criterio 12):** aquí se define el problema y se verifica el entorno. **No se limpia, no se imputa y no se transforma** el dataset — eso corresponde al notebook de la Fase 2.

# %% [markdown]
# ## 1. Contexto y formulación del problema
#
# Dataset:
# [📱💻 Mental Health & Technology Usage Dataset 🌱](https://www.kaggle.com/datasets/waqi786/mental-health-and-technology-usage-dataset)
# Este conjunto de datos ofrece información sobre cómo el uso diario de la tecnología —incluyendo las redes sociales y el tiempo frente a la pantalla— afecta a la salud mental. 📊 Recopila diversos patrones de comportamiento y sus correlaciones con indicadores de salud mental, tales como los niveles de estrés, la calidad del sueño y la productividad. ¡Explóralo para analizar la relación entre nuestras vidas digitales y el bienestar mental! 🌟
#
# Estos datos resultan útiles para investigaciones, proyectos académicos o el desarrollo de modelos predictivos que permitan comprender las tendencias de salud mental influidas por el tiempo de pantalla y los hábitos tecnológicos. 🔍📉

# %% [markdown]
# ## 2. Preguntas de análisis
#
# _¿Qué relación existe entre los patrones de uso de la tecnología y los indicadores de salud mental, estrés y calidad del sueño de las personas?_
# - ¿Cómo varía el estado de salud mental según las horas diarias de uso de tecnología?
# - ¿Las personas con más horas de actividad física presentan una distribución distinta?
# - ¿Cómo varían tecnología, sueño, actividad física y estrés entre grupos de edad?

# %% [markdown]
# ## 3. Objetivo general
#
# Analizar y evaluar la relación entre los patrones de uso de tecnología y los indicadores de salud mental, estrés, calidad del sueño y actividad física, mediante un flujo de trabajo reproducible, documentado y colaborativo.

# %% [markdown]
# ## 4. Objetivos específicos
#
# 1. Configurar un entorno de trabajo reproducible (Python, entorno virtual, Jupyter, Git/GitHub).
# 2. Obtener, explorar y diagnosticar la calidad del dataset Mental Health and Technology Usage.
# 3. Limpiar y transformar el dataset, justificando cada decisión técnica adoptada.
# 4. Validar el dataset resultante mediante pruebas de casos normales, límite y de excepción.
# 5. Cuantificar las asociaciones observadas considerando significancia estadística identificar relaciones relevantes, débiles o inexistentes.
# 6. Caracterizar la relación entre uso de tecnología, estrés, salud mental y sueño (Fases 3-4).

# %% [markdown]
# ## 5. Alcance, restricciones y supuestos
#
# **Alcance:** Este informe cubre exclusivamente las Fases 1 y 2: definición del problema, configuración del entorno y desarrollo del pipeline de datos (obtención, exploración, limpieza, transformación y validación).
#
# **Supuestos:** La completitud de los datos y el comportamiento de las variables requiere considerar la posibilidad de que se trate de datos sintéticos, y preparados por los dueños de los datos; sin embargo, no todas las columnas del dataset son significativas para el análisis.

# %% [markdown]
# ## 6. Configuración y verificación del entorno
#
# Código base que evidencia que el entorno reproducible está funcionando.

# %%
import sys
print('Python:', sys.version)

# Verificar librerías clave del entorno
import pandas as pd
import numpy as np
print('pandas:', pd.__version__)
print('numpy:', np.__version__)

# %% [markdown]
# ## 7. Reconocimiento inicial del conjunto de datos
#
# Solo carga y una mirada superficial — sin limpiar ni transformar (eso es F2).

# %%
from pathlib import Path

RUTA = ""  # completar: ruta al archivo del dataset
df = pd.read_csv(RUTA)

print('Filas, columnas:', df.shape)
df.head()

# %% [markdown]
# ## 8. Vinculación con el mapa conceptual (breve)
#
# Los bloques 1 a 8 del mapa conceptual materializan el avance de las Fases 1 y 2; la modelación y la comunicación visual de resultados, proyectadas en el mapa como trabajo de fases posteriores, se abordarán en las Fases 3 y 4 respectivamente
# _Nota: el desarrollo completo de este punto va en el informe (§2.14, Criterio 14)._

# %% [markdown]
# ---
# **Antes de entregar:** `Kernel → Restart Kernel and Run All Cells` y verificar que corre sin errores de inicio a fin.
